# %% [markdown]
# # <font color='#698B69'>Sentiment Analysis of a Amazon Product.</font>

# %% [markdown]
# >- The link of the product that i have analyzed is 'https://www.amazon.in/boAt-Bassheads-242-Earphones-Carbon/dp/B09FSWY5BP/ref=cm_cr_arp_d_pdt_img_top?ie=UTF8'.

# %%
# importing dependencies
import pandas as pd
import numpy as np
import spacy
import string
import re

from matplotlib.pyplot import imread
from matplotlib import pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline

import nltk
from nltk import tokenize

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
affin = pd.read_csv('Afinn.csv', sep=',', encoding='latin-1')
affin
# Out:
#            word  value
# 0       abandon     -2
# 1     abandoned     -2
# 2      abandons     -2
# 3      abducted     -2
# 4     abduction     -2
# ...         ...    ...
# 2472      yucky     -2
# 2473      yummy      3
# 2474     zealot     -2
# 2475    zealots     -2
# 2476    zealous      2
#
# [2477 rows x 2 columns]

# %%
df = pd.read_csv('boat_Bassheads_242.csv')
df.head()
# Out:
#                                         product_name  \
# 0  boAt Bassheads 242 in Ear Wired Earphones with...
# 1  boAt Bassheads 242 in Ear Wired Earphones with...
# 2  boAt Bassheads 242 in Ear Wired Earphones with...
# 3  boAt Bassheads 242 in Ear Wired Earphones with...
# 4  boAt Bassheads 242 in Ear Wired Earphones with...
#
#                                                title  stars  \
# 0                 Overall good package. Fond of this    5.0
# 1  After almost1 week right earplug isn't working...    1.0
# 2                  Best. Using it since a month now!    5.0
# 3                                    Horrible sound.    1.0
# 4                 Warranty issue.....How to return ?    3.0
#
#                                                 body
# 0  If you want durable earphone, protected from s...
# 1  Before these earphones, I used the basic Samsu...
# 2  Best for me. If you fall in the middle categor...
# 3  Worst sound. It's like someone is poking you w...
# 4  One side of these ear plugs stopped working wi...

# %%
df.shape
# Out:
# (1630, 4)

# %% [markdown]
# ## <font color='#698B69'>Text preprocessing</font>

# %%
#function for text preprocessing
def get_cleanText(text):
    text = re.sub(r'@[A-Za-z0-9]+','',text)#removes username
    text = re.sub(r'#','',text)
    text = re.sub(r'RT[\s]+','',text)
    text = re.sub(r'https?:\/\/\S+','',text)# removes hyperlink
    text=  re.sub("[^A-Za-z" "]+"," ",text) #removes special characters
    return text

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\CHINU\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text = [x.strip() for x in df.body] # remove both the leading and the trailing characters
text = [x for x in text if x] # removes empty strings, because they are considered in Python as False
#text

# %%
#tokenize 
tokens = tokenize.sent_tokenize(" ".join(text))
tokens[5:15]
# Out:
# ['Couldve been provided more.Overall you can surely take this if you badly need waterproofing and durability, otherwise 225/152/162 has slightly better sound.',
#  'But this has volume control keys, thats a plus point.',
#  'Before these earphones, I used the basic Samsung earphones which were 5 years old.And I am writing this review after 3 days of usage,daily for 3-4 hours.Pros:  1- Crystal clear & loud sound.',
#  '5/52- Amazing bass.',
#  '5/53-Call quality is fine.',
#  '4/54- The wires are braided which make them more durable.',
#  '5/5One of the most amazing features is that you get sound control buttons in this earphones which work as a charm.Cons :1- After continuous use for 45-60 mins, they cause pain in ears.2- They are MADE IN CHINA.',
#  "I didn't know it before.Edit: After daily usage of almost 1 week, the right earplug is not working properly and they are causing hell lot of pain and itchiness on the ear.I am reducing the rating from 4 stars to 1.",
#  "Also I have applied for replacement.I really wish, somehow refund would be possible, as I don't want to waste 500 Rs.",
#  'Best for me.']

# %%
new_df = pd.DataFrame(tokens, columns=['sentence'])
new_df
# Out:
#                                                sentence
# 0     If you want durable earphone, protected from s...
# 1     Go for this.Build quality: Very good form fact...
# 2     Eartips are comfortable and fits nicely, looks...
# 3                                Could've been thicker.
# 4             Extra eartips only 2 small and 2 mediums.
# ...                                                 ...
# 4220  But they are very good.... Why this is faulty....
# 4221  The sound quality is to good and the noise can...
# 4222  The product has excellent sound quality and al...
# 4223  It has anacceptable bass quality.The product p...
# 4224  boat never disappoint... all products of boats...
#
# [4225 rows x 1 columns]

# %%
df['clean_text']=new_df['sentence'].apply(get_cleanText)
print(df['clean_text'])
# Out:
# 0       If you want durable earphone protected from sw...
# 1       Go for this Build quality Very good form facto...
# 2       Eartips are comfortable and fits nicely looks ...
# 3                                  Could ve been thicker
# 4                   Extra eartips only small and mediums
#                               ...
# 1625    Others are different models and they still wor...
# 1626                                As always NO REGRETS
# 1627                         It s very good for the rate
# 1628                                    Easy to use thin
# 1629    I got a spirit lime color and it s awesome esp...
# Name: clean_text, Length: 1630, dtype: object

# %%
affinity_scores = affin.set_index('word')['value'].to_dict()

# %%
nlp = spacy.load('en_core_web_sm')
sentiment_lexicon = affinity_scores

# %%
#function to get the sentiment score
def calculate_sentiment(text: str = None):
    sent_score = 0
    if text:
        sentence = nlp(text)
        for word in sentence:
            sent_score += sentiment_lexicon.get(word.lemma_, 0)# return the score if the word is in the dict otherwise 0
    return sent_score

# %%
calculate_sentiment(text = 'hate')
# Out:
# -3

# %%
df['sentiment_value'] = df['clean_text'].apply(calculate_sentiment)
df
# Out:
#                                            product_name  \
# 0     boAt Bassheads 242 in Ear Wired Earphones with...
# 1     boAt Bassheads 242 in Ear Wired Earphones with...
# 2     boAt Bassheads 242 in Ear Wired Earphones with...
# 3     boAt Bassheads 242 in Ear Wired Earphones with...
# 4     boAt Bassheads 242 in Ear Wired Earphones with...
# ...                                                 ...
# 1625  boAt Bassheads 242 in Ear Wired Earphones with...
# 1626  boAt Bassheads 242 in Ear Wired Earphones with...
# 1627  boAt Bassheads 242 in Ear Wired Earphones with...
# 1628  boAt Bassheads 242 in Ear Wired Earphones with...
# 1629  boAt Bassheads 242 in Ear Wired Earphones with...
#
#                                                   title  stars  \
# 0                    Overall good package. Fond of this    5.0
# 1     After almost1 week right earplug isn't working...    1.0
# 2                     Best. Using it since a month now!    5.0
# 3                                       Horrible sound.    1.0
# 4                    Warranty issue.....How to return ?    3.0
# ...                                                 ...    ...
# 1625  Amazing Performance..!! One of the best produc...    5.0
# 1626                                               best    5.0
# 1627                                  The sound quality    5.0
# 1628  If you are looking for best bass earphone then...    3.0
# 1629            Worst earphone don't waste your money..    1.0
#
#                                                    body  \
# 0     If you want durable earphone, protected from s...
# 1     Before these earphones, I used the basic Samsu...
# 2     Best for me. If you fall in the middle categor...
# 3     Worst sound. It's like someone is poking you w...
# 4     One side of these ear plugs stopped working wi...
# ...                                                 ...
# 1625  The product has excellent sound quality and al...
# 1626  boat never disappoint... all products of boats...
# 1627  Its a good product for 500rsWhen I watching th...
# 1628  Sound quality is goodBut bass is not to much a...
# 1629  Worst earphone i ever purchased, 2 month only ...
#
#                                              clean_text  sentiment_value
# 0     If you want durable earphone protected from sw...                2
# 1     Go for this Build quality Very good form facto...                3
# 2     Eartips are comfortable and fits nicely looks ...                6
# 3                                Could ve been thicker                 0
# 4                 Extra eartips only small and mediums                 0
# ...                                                 ...              ...
# 1625  Others are different models and they still wor...                5
# 1626                              As always NO REGRETS                -1
# 1627                       It s very good for the rate                 3
# 1628                                  Easy to use thin                 1
# 1629  I got a spirit lime color and it s awesome esp...                8
#
# [1630 rows x 6 columns]

# %%
df['word_count'] = df['clean_text'].str.split().apply(len)
df
# Out:
#                                            product_name  \
# 0     boAt Bassheads 242 in Ear Wired Earphones with...
# 1     boAt Bassheads 242 in Ear Wired Earphones with...
# 2     boAt Bassheads 242 in Ear Wired Earphones with...
# 3     boAt Bassheads 242 in Ear Wired Earphones with...
# 4     boAt Bassheads 242 in Ear Wired Earphones with...
# ...                                                 ...
# 1625  boAt Bassheads 242 in Ear Wired Earphones with...
# 1626  boAt Bassheads 242 in Ear Wired Earphones with...
# 1627  boAt Bassheads 242 in Ear Wired Earphones with...
# 1628  boAt Bassheads 242 in Ear Wired Earphones with...
# 1629  boAt Bassheads 242 in Ear Wired Earphones with...
#
#                                                   title  stars  \
# 0                    Overall good package. Fond of this    5.0
# 1     After almost1 week right earplug isn't working...    1.0
# 2                     Best. Using it since a month now!    5.0
# 3                                       Horrible sound.    1.0
# 4                    Warranty issue.....How to return ?    3.0
# ...                                                 ...    ...
# 1625  Amazing Performance..!! One of the best produc...    5.0
# 1626                                               best    5.0
# 1627                                  The sound quality    5.0
# 1628  If you are looking for best bass earphone then...    3.0
# 1629            Worst earphone don't waste your money..    1.0
#
#                                                    body  \
# 0     If you want durable earphone, protected from s...
# 1     Before these earphones, I used the basic Samsu...
# 2     Best for me. If you fall in the middle categor...
# 3     Worst sound. It's like someone is poking you w...
# 4     One side of these ear plugs stopped working wi...
# ...                                                 ...
# 1625  The product has excellent sound quality and al...
# 1626  boat never disappoint... all products of boats...
# 1627  Its a good product for 500rsWhen I watching th...
# 1628  Sound quality is goodBut bass is not to much a...
# 1629  Worst earphone i ever purchased, 2 month only ...
#
#                                              clean_text  sentiment_value  \
# 0     If you want durable earphone protected from sw...                2
# 1     Go for this Build quality Very good form facto...                3
# 2     Eartips are comfortable and fits nicely looks ...                6
# 3                                Could ve been thicker                 0
# 4                 Extra eartips only small and mediums                 0
# ...                                                 ...              ...
# 1625  Others are different models and they still wor...                5
# 1626                              As always NO REGRETS                -1
# 1627                       It s very good for the rate                 3
# 1628                                  Easy to use thin                 1
# 1629  I got a spirit lime color and it s awesome esp...                8
#
#       word_count
# 0              9
# 1             14
# 2             44
# 3              4
# 4              6
# ...          ...
# 1625          19
# 1626           4
# 1627           7
# 1628           4
# 1629          24
#
# [1630 rows x 7 columns]

# %%
#Top positive reviews
df.sort_values(by='sentiment_value',ascending=False).head(10)
# Out:
#                                            product_name  \
# 936   boAt Bassheads 242 in Ear Wired Earphones with...
# 202   boAt Bassheads 242 in Ear Wired Earphones with...
# 758   boAt Bassheads 242 in Ear Wired Earphones with...
# 791   boAt Bassheads 242 in Ear Wired Earphones with...
# 1029  boAt Bassheads 242 in Ear Wired Earphones with...
# 1238  boAt Bassheads 242 in Ear Wired Earphones with...
# 1553  boAt Bassheads 242 in Ear Wired Earphones with...
# 135   boAt Bassheads 242 in Ear Wired Earphones with...
# 1088  boAt Bassheads 242 in Ear Wired Earphones with...
# 771   boAt Bassheads 242 in Ear Wired Earphones with...
#
#                                               title  stars  \
# 936                                        snug fit    5.0
# 202                          Won't suit in long run    2.0
# 758   Best earphone, good sound quality and painful    4.0
# 791                                         Overall    5.0
# 1029                   DO NOT BUY... WASTE OF MONEY    1.0
# 1238                  Not happy with Amazon service    1.0
# 1553                                      Worth buy    5.0
# 135                                            Good    3.0
# 1088                                           Good    4.0
# 771                                 Best for Sports    4.0
#
#                                                    body  \
# 936   the problem with many sport earphone is that t...
# 202   I have been using it for a couple of months. T...
# 758   I'm really like this earphone. The sound quali...
# 791   This is my second time for getting the boat he...
# 1029  PL DO NOT BUY THIS AT ALLVoice not clear at al...
# 1238  During call it's automatically disconnected an...
# 1553       Worth the money u spend.. good sound quality
# 135   Im giving 3 star because of the product that i...
# 1088  Audio quality is good. It has a extra two sets...
# 771   It is best for almost every sports activities....
#
#                                              clean_text  sentiment_value  \
# 936    They say its IPX i haven t used it in such co...               29
# 202   Just got this after day and i can say the qual...               29
# 758   I have been using it now for months Quality th...               27
# 791   There Can t be a better Product than this Tota...               26
# 1029  Recommend After using for months the best I ca...               26
# 1238  And can be used for calls Super product for ga...               25
# 1553  Not even replying via email I m still using th...               22
# 135   Only benefit I found is that it has inline mic...               21
# 1088  Best budget earphone with good sound quality a...               20
# 771   I hv many earphones like models of Boult and t...               19
#
#       word_count
# 936          136
# 202          274
# 758           82
# 791          130
# 1029         112
# 1238         185
# 1553         116
# 135           74
# 1088          42
# 771           65

# %%
#Summarized sentiment
df['sentiment_value'].describe()
# Out:
# count    1630.000000
# mean        1.698773
# std         3.941648
# min       -10.000000
# 25%         0.000000
# 50%         0.000000
# 75%         3.000000
# max        29.000000
# Name: sentiment_value, dtype: float64

# %%
sns.set_theme(context='notebook',style='white',palette='gist_earth_r',font_scale=1.8)

# %%
plt.title("Sentiment Analysis")
sns.set(rc={"figure.figsize":(18, 8)})
sns.distplot(df['sentiment_value'],color='#698B69');

# %%
plt.title("Word_count VS Sentiment Value")
sns.set(rc={"figure.figsize":(18, 8)})
sns.scatterplot(x=df['sentiment_value'],y=df['word_count']);

# %% [markdown]
# ## <font color='#698B69'> Using TextBlob </font>

# %%
from textblob import TextBlob

# %%
#function to get subjectivity
def get_Subjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# %%
#function to get polarity(positive or negative)
def get_Polarity(text):
    return TextBlob(text).sentiment.polarity

# %%
final_df = df.iloc[:,2:5]
final_df["subjectivity"]= final_df['clean_text'].apply(get_Subjectivity)
final_df["polarity"]= final_df['clean_text'].apply(get_Polarity)

# %%
final_df
# Out:
#       stars                                               body  \
# 0       5.0  If you want durable earphone, protected from s...
# 1       1.0  Before these earphones, I used the basic Samsu...
# 2       5.0  Best for me. If you fall in the middle categor...
# 3       1.0  Worst sound. It's like someone is poking you w...
# 4       3.0  One side of these ear plugs stopped working wi...
# ...     ...                                                ...
# 1625    5.0  The product has excellent sound quality and al...
# 1626    5.0  boat never disappoint... all products of boats...
# 1627    5.0  Its a good product for 500rsWhen I watching th...
# 1628    3.0  Sound quality is goodBut bass is not to much a...
# 1629    1.0  Worst earphone i ever purchased, 2 month only ...
#
#                                              clean_text  subjectivity  \
# 0     If you want durable earphone protected from sw...      0.000000
# 1     Go for this Build quality Very good form facto...      0.780000
# 2     Eartips are comfortable and fits nicely looks ...      0.536111
# 3                                Could ve been thicker       0.000000
# 4                 Extra eartips only small and mediums       0.500000
# ...                                                 ...           ...
# 1625  Others are different models and they still wor...      0.551515
# 1626                              As always NO REGRETS       0.200000
# 1627                       It s very good for the rate       0.780000
# 1628                                  Easy to use thin       0.841667
# 1629  I got a spirit lime color and it s awesome esp...      1.000000
#
#       polarity
# 0     0.000000
# 1     0.910000
# 2     0.225000
# 3     0.000000
# 4    -0.083333
# ...        ...
# 1625  0.278788
# 1626  0.050000
# 1627  0.910000
# 1628  0.016667
# 1629  0.533333
#
# [1630 rows x 5 columns]

# %%
#plotting the words
allwords = ' '.join([word for word in final_df['clean_text']])
wc = WordCloud(width=700,height=500,random_state=4,max_font_size=150).generate(allwords)

plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.show();

# %%
#function to compute whether a review is positive or negative
def get_score(score):
    score = float(score)
    if (score < 0):
        return 'Negative'
    elif (score == 0):
        return 'Neutral'
    elif score > 0:
        return 'Positive'

# %%
final_df['sentiment'] = final_df['polarity'].apply(get_score)

# %%
plt.title("Sentimental Analysis")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.style.use('seaborn-dark-palette')
final_df['sentiment'].value_counts().plot(kind='bar');

# %% [markdown]
# > Most of the Reviews are Positive.

# %%
#getting the percentage of positive tweets
positive=final_df[final_df['polarity']>0]
ptweets = positive['clean_text']
score = round(ptweets.shape[0]/final_df.shape[0] *100)
print("The percentage of positive tweets is {} %.".format(score))
# Out:
# The percentage of positive tweets is 57 %.
